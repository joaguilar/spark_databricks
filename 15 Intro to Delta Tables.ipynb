-- %% [markdown]
-- # 15 Intro to Delta Tables

-- %%
%python
# Celda de configuración (primera celda de código del notebook)
CATALOG = "big_data_ii_2025"
SCHEMA  = "spark_examples"
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.{SCHEMA}")
spark.sql(f"USE CATALOG {CATALOG}")
spark.sql(f"USE SCHEMA {SCHEMA}")
print(f"Trabajando en {CATALOG}.{SCHEMA}")

-- %% [markdown]
-- # Crear Tabla
--
-- Creamos la tabla de forma autocontenida, con los datos definidos directamente en la consulta (sin depender de archivos externos), para garantizar que el notebook corra igual en cualquier cuenta de Free Edition.

-- %%
%sql
USE CATALOG big_data_ii_2025;
USE SCHEMA spark_examples;
DROP TABLE IF EXISTS people_delta;

CREATE TABLE IF NOT EXISTS people_delta
USING DELTA
AS
SELECT
  row_number() OVER (ORDER BY _c0) AS id,
  _c0 AS name,
  CAST(_c1 AS INT) AS age
FROM
  csv.`/Volumes/big_data_ii_2025/spark_examples/spark_data/people.csv`;

-- %% [markdown]
-- > **Antes de ejecutar:** ¿Qué columnas y tipos esperas ver en `people_delta`? ¿De qué tipo quedó `age`?

-- %%
DESCRIBE people_delta

-- %% [markdown]
--  Seleccionar los datos y ver que fueran cargados correctamente

-- %%
SELECT * FROM people_delta;

-- %% [markdown]
-- # Actualizaciones
--
-- Actualizar: incrementar age en 1 para id = 3 (Alejandro Duarte)

-- %% [markdown]
-- > **Antes de ejecutar:** ¿Qué edad tiene ahora el registro con id = 3?

-- %%
SELECT * FROM people_delta WHERE id = 3

-- %% [markdown]
-- > **Antes de ejecutar:** ¿Cuántas filas reportará Spark como afectadas por este UPDATE?

-- %%
UPDATE people_delta
SET age = age + 1
WHERE id = 3;

-- %% [markdown]
-- Verificamos que el `UPDATE` haya incrementado la edad en 1.

-- %%
SELECT * FROM people_delta WHERE id = 3

-- %% [markdown]
-- # Mas Actualizaciones
--
-- Eliminar registros de menores de 20 años

-- %%
SELECT * FROM people_delta WHERE age < 20

-- %% [markdown]
-- > **Antes de ejecutar:** ¿Cuántas filas se van a eliminar con esta condición? Mira los datos cargados arriba.

-- %%
DELETE FROM people_delta WHERE age < 20;

-- %% [markdown]
-- Confirmamos que ya no quedan registros con `age < 20`.

-- %%
SELECT * FROM people_delta WHERE age < 20

-- %% [markdown]
-- # Historial de cambios
--
-- Podemos ver todas las acciones ejecutadas sobre la tabla por medio del comando DESCRIBE HISTORY

-- %% [markdown]
-- > **Antes de ejecutar:** ¿Cuántas versiones esperas en el historial hasta este punto, y qué operación corresponde a cada una?

-- %%
DESCRIBE HISTORY people_delta;
