# %%
from kafka import KafkaConsumer
import json

# %% [markdown]
# # Ejemplo: Leer mensajes
#
# Podemos entonces sacar mensajes de la cola `temperature`

# %%
consumer = KafkaConsumer('temperatura',
                     bootstrap_servers=['localhost:9092'],
                     auto_offset_reset='earliest',
                     value_deserializer=lambda m: json.loads(m.decode()))
i = 0
max_messages = 100
for msg in consumer:
    if i >= max_messages:
        break
    print(msg.value)
    i += 1
# Out:
# {'sensor': 's2', 'value': 27}
# {'sensor': 's3', 'value': 32}
# {'sensor': 's3', 'value': 35}
# {'sensor': 's3', 'value': 27}
# {'sensor': 's1', 'value': 29}
# {'sensor': 's4', 'value': 20}
# {'sensor': 's4', 'value': 17}
# {'sensor': 's1', 'value': 17}
# {'sensor': 's2', 'value': 32}
# {'sensor': 's4', 'value': 33}
# {'sensor': 's4', 'value': 22}
# {'sensor': 's5', 'value': 22}
# {'sensor': 's4', 'value': 16}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       1 consumer = KafkaConsumer('temperatura',
#       2                      bootstrap_servers=['localhost:9092'],
#       3                      auto_offset_reset='earliest',
#       4                      value_deserializer=lambda m: json.loads(m.decode()))
# ----> 5 for msg in consumer:
#       6         print(msg.value)
#
# File ~/Documents/Development/databricks/spark_databricks/.venv/lib/python3.9/site-packages/kafka/consumer/group.py:1188, in KafkaConsumer.__next__(self)
#    1186     self._iterator = self._message_generator_v2()
#    1187 try:
# -> 1188     return next(self._iterator)
#    1189 except StopIteration:
#    1190     self._iterator = None
#
# File ~/Documents/Development/databricks/spark_databricks/.venv/lib/python3.9/site-packages/kafka/consumer/group.py:1160, in KafkaConsumer._message_generator_v2(self)
#    1158 def _message_generator_v2(self):
#    1159     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1160     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1161     for tp, records in six.iteritems(record_map):
#    1162         # Generators are stateful, and it is possible that the tp / records
#    1163         # here may become stale during iteration -- i.e., we seek to a
#    1164         # different offset, pause consumption, or lose assignment.
#    1165         for record in records:
#    1166             # is_fetchable(tp) should handle assignment changes and offset
#    1167             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1168             # outer function destroying the existing iterator/generator
#    1169             # via self._iterator = None
#
# File ~/Documents/Development/databricks/spark_databricks/.venv/lib/python3.9/site-packages/kafka/consumer/group.py:684, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     682 timer = Timer(timeout_ms)
#     683 while not self._closed:
# --> 684     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     685     if records:
#     686         return records
#
# File ~/Documents/Development/databricks/spark_databricks/.venv/lib/python3.9/site-packages/kafka/consumer/group.py:731, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     728     log.debug('poll: do not have all fetch positions...')
#     729     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 731 self._client.poll(timeout_ms=poll_timeout_ms)
#     732 # after the long poll, we should check whether the group needs to rebalance
#     733 # prior to returning data so that the group can stabilize faster
#     734 if self._coordinator.need_rejoin():
#
# File ~/Documents/Development/databricks/spark_databricks/.venv/lib/python3.9/site-packages/kafka/client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File ~/Documents/Development/databricks/spark_databricks/.venv/lib/python3.9/site-packages/kafka/client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File /opt/homebrew/Cellar/python@3.9/3.9.21/Frameworks/Python.framework/Versions/3.9/lib/python3.9/selectors.py:562, in KqueueSelector.select(self, timeout)
#     560 ready = []
#     561 try:
# --> 562     kev_list = self._selector.control(None, max_ev, timeout)
#     563 except InterruptedError:
#     564     return ready
#
# KeyboardInterrupt:

# %%
cons = KafkaConsumer('temperatura',
                     bootstrap_servers=['localhost:9092'],
                     auto_offset_reset='earliest',
                     value_deserializer=lambda m: json.loads(m.decode()))
for msg in cons:
    print(msg.value)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[4], line 7
#       2 import json
#       3 cons = KafkaConsumer('temperatura',
#       4                      bootstrap_servers=['localhost:9092'],
#       5                      auto_offset_reset='earliest',
#       6                      value_deserializer=lambda m: json.loads(m.decode()))
# ----> 7 for msg in cons:
#       8     print(msg.value)
#
# File ~/Documents/Development/databricks/spark_databricks/.venv/lib/python3.9/site-packages/kafka/consumer/group.py:1188, in KafkaConsumer.__next__(self)
#    1186     self._iterator = self._message_generator_v2()
#    1187 try:
# -> 1188     return next(self._iterator)
#    1189 except StopIteration:
#    1190     self._iterator = None
#
# File ~/Documents/Development/databricks/spark_databricks/.venv/lib/python3.9/site-packages/kafka/consumer/group.py:1160, in KafkaConsumer._message_generator_v2(self)
#    1158 def _message_generator_v2(self):
#    1159     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1160     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1161     for tp, records in six.iteritems(record_map):
#    1162         # Generators are stateful, and it is possible that the tp / records
#    1163         # here may become stale during iteration -- i.e., we seek to a
#    1164         # different offset, pause consumption, or lose assignment.
#    1165         for record in records:
#    1166             # is_fetchable(tp) should handle assignment changes and offset
#    1167             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1168             # outer function destroying the existing iterator/generator
#    1169             # via self._iterator = None
#
# File ~/Documents/Development/databricks/spark_databricks/.venv/lib/python3.9/site-packages/kafka/consumer/group.py:684, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     682 timer = Timer(timeout_ms)
#     683 while not self._closed:
# --> 684     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     685     if records:
#     686         return records
#
# File ~/Documents/Development/databricks/spark_databricks/.venv/lib/python3.9/site-packages/kafka/consumer/group.py:738, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     735     log.debug('poll: coordinator needs rejoin; returning early')
#     736     return {}
# --> 738 records, _ = self._fetcher.fetched_records(max_records, update_offsets=update_offsets)
#     739 return records
#
# File ~/Documents/Development/databricks/spark_databricks/.venv/lib/python3.9/site-packages/kafka/consumer/fetcher.py:351, in Fetcher.fetched_records(self, max_records, update_offsets)
#     349 except Exception as e:
#     350     if not drained:
# --> 351         raise e
#     352     # To be thrown in the next call of this method
#     353     self._next_in_line_exception_metadata = ExceptionMetadata(fetched_partition, fetched_offset, e)
#
# File ~/Documents/Development/databricks/spark_databricks/.venv/lib/python3.9/site-packages/kafka/consumer/fetcher.py:345, in Fetcher.fetched_records(self, max_records, update_offsets)
#     343             fetched_partition = self._next_partition_records.topic_partition
#     344             fetched_offset = self._next_partition_records.next_fetch_offset
# --> 345             records_remaining -= self._append(drained,
#     346                                               self._next_partition_records,
#     347                                               records_remaining,
#     348                                               update_offsets)
#     349 except Exception as e:
#     350     if not drained:
#
# File ~/Documents/Development/databricks/spark_databricks/.venv/lib/python3.9/site-packages/kafka/consumer/fetcher.py:379, in Fetcher._append(self, drained, part, max_records, update_offsets)
#     376 if part.next_fetch_offset == position.offset:
#     377     log.debug("Returning fetched records at offset %d for assigned"
#     378               " partition %s", position.offset, tp)
# --> 379     part_records = part.take(max_records)
#     380     # list.extend([]) is a noop, but because drained is a defaultdict
#     381     # we should avoid initializing the default list unless there are records
#     382     if part_records:
#
# File ~/Documents/Development/databricks/spark_databricks/.venv/lib/python3.9/site-packages/kafka/consumer/fetcher.py:977, in Fetcher.PartitionRecords.take(self, n)
#     975 except Exception as e:
#     976     if not records:
# --> 977         raise e
#     978     # To be thrown in the next call of this method
#     979     self._next_inline_exception = e
#
# File ~/Documents/Development/databricks/spark_databricks/.venv/lib/python3.9/site-packages/kafka/consumer/fetcher.py:974, in Fetcher.PartitionRecords.take(self, n)
#     971 records = []
#     972 try:
#     973     # Note that records.extend(iter) will extend partially when exception raised mid-stream
# --> 974     records.extend(itertools.islice(self.record_iterator, 0, n))
#     975 except Exception as e:
#     976     if not records:
#
# File ~/Documents/Development/databricks/spark_databricks/.venv/lib/python3.9/site-packages/kafka/consumer/fetcher.py:1034, in Fetcher.PartitionRecords._unpack_records(self, tp, records, key_deserializer, value_deserializer)
#    1032 value_size = len(record.value) if record.value is not None else -1
#    1033 key = self._deserialize(key_deserializer, tp.topic, record.key)
# -> 1034 value = self._deserialize(value_deserializer, tp.topic, record.value)
#    1035 headers = record.headers
#    1036 header_size = sum(
#    1037     len(h_key.encode("utf-8")) + (len(h_val) if h_val is not None else 0) for h_key, h_val in
#    1038     headers) if headers else -1
#
# File ~/Documents/Development/databricks/spark_databricks/.venv/lib/python3.9/site-packages/kafka/consumer/fetcher.py:1070, in Fetcher.PartitionRecords._deserialize(self, f, topic, bytes_)
#    1068 if isinstance(f, Deserializer):
#    1069     return f.deserialize(topic, bytes_)
# -> 1070 return f(bytes_)
#
# Cell In[4], line 6, in <lambda>(m)
#       1 from kafka import KafkaConsumer
#       2 import json
#       3 cons = KafkaConsumer('temperatura',
#       4                      bootstrap_servers=['localhost:9092'],
#       5                      auto_offset_reset='earliest',
# ----> 6                      value_deserializer=lambda m: json.loads(m.decode()))
#       7 for msg in cons:
#       8     print(msg.value)
#
# File /opt/homebrew/Cellar/python@3.9/3.9.21/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /opt/homebrew/Cellar/python@3.9/3.9.21/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /opt/homebrew/Cellar/python@3.9/3.9.21/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
