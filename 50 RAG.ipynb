# %% [markdown]
# # 50 RAG
#
# Este notebook presenta el flujo del ejercicio paso a paso, con notas para entender qué hace cada bloque y cómo validar los resultados mientras avanzas.
#
# ## Objetivo
# Comprender el propósito de cada parte del código y su relación con el proceso completo en Spark.
#
# ## Antes de ejecutar
# - Verifica que la sesión de Spark esté activa y sin errores.
# - Confirma que las rutas de entrada existan en tu entorno.
# - Ejecuta las celdas en orden para mantener dependencias.
#
# ## Orden recomendado
# 1. Ejecuta configuración e importaciones.
# 2. Carga datos y valida esquema y volumen.
# 3. Aplica transformaciones revisando salidas intermedias.
# 4. Interpreta resultados analíticos o métricas de modelo.
# 5. Ejecuta escrituras finales validando destino y formato.
#
# ## Verificación
# - Puedes explicar qué entra y qué sale en cada transformación.
# - Los resultados intermedios son coherentes con la lógica aplicada.
# - El resultado final responde al objetivo del ejercicio.

# %% [markdown]
# Este bloque construye o evalúa un flujo de *Machine Learning* en Spark (preparación de variables, entrenamiento o validación del modelo).
#
# Sugerencia de ejecución: Ejecuta esta celda después de preparar el dataset y verifica métricas de desempeño para interpretar si el modelo está aprendiendo correctamente.

# %%
# %pip install sentence-transformers
# %pip install databricks-vectorsearch mlflow openai
dbutils.library.restartPython()

# %% [markdown]
# Este bloque ejecuta una parte del flujo de procesamiento en Spark y aporta resultados para las siguientes celdas.
#
# Sugerencia de ejecución: Ejecuta esta celda de forma secuencial respecto al notebook y revisa la salida para comprender su aporte al objetivo del ejercicio.

# %%
from openai import OpenAI
import os
from pyspark.sql.functions import col, udf
from pyspark.sql.types import ArrayType, FloatType

# How to get your Databricks token: https://docs.databricks.com/en/dev-tools/auth/pat.html
# DATABRICKS_TOKEN = os.environ.get('DATABRICKS_TOKEN')
# Alternatively in a Databricks notebook you can use this:
DATABRICKS_TOKEN = dbutils.notebook.entry_point.getDbutils().notebook().getContext().apiToken().get()

def get_embedding(text):
    client = OpenAI(
        api_key=DATABRICKS_TOKEN,
        base_url="https://dbc-504c50c9-8143.cloud.databricks.com/serving-endpoints"
    )
    response = client.embeddings.create(input=text, model="databricks-gte-large-en")
    return response.data[0].embedding

# %% [markdown]
# Este bloque ejecuta una parte del flujo de procesamiento en Spark y aporta resultados para las siguientes celdas.
#
# Sugerencia de ejecución: Ejecuta esta celda de forma secuencial respecto al notebook y revisa la salida para comprender su aporte al objetivo del ejercicio.

# %%
# %sql
USE CATALOG `big_data_ii_2025`;
USE SCHEMA `spark_examples`;
SELECT id, text from test_text_embeddings;

# %% [markdown]
# Este bloque prepara librerías y dependencias que se usarán en el resto del notebook.
#
# Sugerencia de ejecución: Ejecuta esta celda al inicio y confirma que no aparezcan errores de importación antes de continuar con el laboratorio.

# %%
from databricks.vector_search.client import VectorSearchClient

# %% [markdown]
# Este bloque ejecuta una parte del flujo de procesamiento en Spark y aporta resultados para las siguientes celdas.
#
# Sugerencia de ejecución: Ejecuta esta celda de forma secuencial respecto al notebook y revisa la salida para comprender su aporte al objetivo del ejercicio.

# %%
vsc = VectorSearchClient()

# Trigger indexing for the vector search index
# vsc.start_indexing(
#     index_name="big_data_ii_2025.spark_examples.test_vector_search_index"
# )

index = vsc.get_index(
    index_name="big_data_ii_2025.spark_examples.test_vector_search_index"
)
index.sync()

# %% [markdown]
# Este bloque inspecciona resultados intermedios para validar que las transformaciones previas sean correctas.
#
# Sugerencia de ejecución: Ejecuta esta celda como punto de control y utiliza la salida para decidir si continuar o ajustar pasos anteriores.

# %%
index.describe()

# %% [markdown]
# Este bloque inspecciona resultados intermedios para validar que las transformaciones previas sean correctas.
#
# Sugerencia de ejecución: Ejecuta esta celda como punto de control y utiliza la salida para decidir si continuar o ajustar pasos anteriores.

# %%
consulta = "¿Cuál es la capital de Inglaterra?"

query_vector = get_embedding(consulta)

index = vsc.get_index(
    index_name="big_data_ii_2025.spark_examples.test_vector_search_index"
)
results = index.similarity_search(
    query_vector=query_vector,
    num_results=2,
    columns=["id", "text"]
)

print(results)

# %% [markdown]
# Este bloque combina datasets mediante operaciones de *join* para enriquecer la información disponible.
#
# Sugerencia de ejecución: Ejecuta esta celda verificando claves de unión y tipo de join, ya que esto impacta directamente en el número de filas resultantes.

# %%
# Extract the index of the "text" column
columns = results['manifest']['columns']
text_idx = next(i for i, col in enumerate(columns) if col['name'] == 'text')

# Concatenate all "text" values into a single string
context = " ".join(row[text_idx] for row in results['result']['data_array'])

print(context)

# %% [markdown]
# Este bloque inspecciona resultados intermedios para validar que las transformaciones previas sean correctas.
#
# Sugerencia de ejecución: Ejecuta esta celda como punto de control y utiliza la salida para decidir si continuar o ajustar pasos anteriores.

# %%
from openai import OpenAI
import os

# How to get your Databricks token: https://docs.databricks.com/en/dev-tools/auth/pat.html
# DATABRICKS_TOKEN = os.environ.get('DATABRICKS_TOKEN')
# Alternatively in a Databricks notebook you can use this:
# DATABRICKS_TOKEN = dbutils.notebook.entry_point.getDbutils().notebook().getContext().apiToken().get()

client = OpenAI(
    api_key=DATABRICKS_TOKEN,
    base_url="https://dbc-504c50c9-8143.cloud.databricks.com/serving-endpoints"
)

response = client.chat.completions.create(
    model="databricks-meta-llama-3-1-8b-instruct",
    messages=[
        {
            "role": "user",
            "content": f"Contesta la pregunta: '{consulta}' usando la información de este contexto: '{context}'"
        }
    ]
)

print(f"La pregunta es '{consulta}'")
print(f"El contexto es '{context}'")
print("==========================================")
print(response.choices[0].message.content)
print("==========================================")
